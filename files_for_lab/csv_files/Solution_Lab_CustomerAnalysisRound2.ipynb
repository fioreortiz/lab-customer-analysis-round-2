# %% [markdown]
# # Lab Customer Analysis Round 2

# %%
import pandas as pd  
import numpy as np

# %%
#1. Show the dataframe shape.
marketing = pd.read_csv('marketing_customer_analysis.csv')
print(type(marketing))
display(marketing.head())
display(marketing.tail(7))
print(marketing.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
#2. Standardize header names
columns = marketing.columns
columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
cols = []
for column in marketing.columns:
    cols.append(column.lower().replace(' ', '_'))
marketing.columns = cols
display(marketing.head())
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# ...

# %%
#3. Which columns are numerical?
marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed:_0                     10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10279 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10279 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
marketing.select_dtypes(['int64','float64'])
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %%
#4. Which columns are categorical?
marketing.select_dtypes(['object'])
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %%
#5. Check and deal with NaN values.
marketing.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
nulls_marketing = pd.DataFrame(round(marketing.isna().sum()/len(marketing),4)*100)
nulls_marketing = nulls_marketing.reset_index()
nulls_marketing.columns = ['header_name', 'percent_nulls']
display(nulls_marketing)
# Out:
#                       header_name  percent_nulls
# 0                      unnamed:_0           0.00
# 1                        customer           0.00
# 2                           state           5.78
# 3         customer_lifetime_value           0.00
# 4                        response           5.78
# 5                        coverage           0.00
# 6                       education           0.00
# 7               effective_to_date           0.00
# 8                employmentstatus           0.00
# 9                          gender           0.00
# 10                         income           0.00
# 11                  location_code           0.00
# 12                 marital_status           0.00
# 13           monthly_premium_auto           0.00
# 14        months_since_last_claim           5.80
# 15  months_since_policy_inception           0.00
# 16      number_of_open_complaints           5.80
# 17             number_of_policies           0.00
# ...

# %%
display(marketing['state'].value_counts(dropna=False)) 
len(marketing[marketing['state'].isna()==True])
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: state, dtype: int64
# 631

# %%
display(marketing['response'].value_counts(dropna=False)) 
len(marketing[marketing['response'].isna()==True])
# Out:
# No     8813
# Yes    1466
# NaN     631
# Name: response, dtype: int64
# 631

# %%
display(marketing['months_since_last_claim'].value_counts(dropna=False)) 
len(marketing[marketing['months_since_last_claim'].isna()==True])
# Out:
# NaN     633
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     378
# 4.0     373
# 2.0     368
# 5.0     355
# 0.0     354
# 10.0    346
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    307
# 17.0    299
# 14.0    299
# 9.0     277
# 19.0    276
# 23.0    276
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    246
# 24.0    237
# 29.0    234
# 28.0    227
# 31.0    221
# 26.0    211
# 27.0    208
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    157
# 32.0    155
# Name: months_since_last_claim, dtype: int64
# 633

# %%
display(marketing['number_of_open_complaints'].value_counts(dropna=False)) 
len(marketing[marketing['number_of_open_complaints'].isna()==True])
# Out:
# 0.0    8160
# 1.0    1145
# NaN     633
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: number_of_open_complaints, dtype: int64
# 633

# %%
display(marketing['vehicle_class'].value_counts(dropna=False)) 
len(marketing[marketing['vehicle_class'].isna()==True])
# Out:
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# NaN               622
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle_class, dtype: int64
# 622

# %%
display(marketing['vehicle_size'].value_counts(dropna=False)) 
len(marketing[marketing['vehicle_size'].isna()==True])
# Out:
# Medsize    7251
# Small      1966
# Large      1071
# NaN         622
# Name: vehicle_size, dtype: int64
# 622

# %%
display(marketing['vehicle_type'].value_counts(dropna=False)) 
len(marketing[marketing['vehicle_type'].isna()==True])
# Out:
# NaN    5482
# A      5428
# Name: vehicle_type, dtype: int64
# 5482

# %%
# After analyzing the data, we can see that the null data is for 5 categorical variables and 2 numerical variables. For both types of variables, the percentage of nulls is 5.80%, with the exception of the variable vehicle_type, which is more than 50%. Since I still don't know what type of further analysis will be required, and in order not to lose information yet, I just do the transformation on the number_of_open_complaints variable to return null values to 0, as it is the most frequent value.

# %%
marketing[marketing['number_of_open_complaints'].isna()==True]
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 4               4  QA50777      Oregon              9025.067525       No
# 23             23  NQ71171  California              5107.071054       No
# 51             51  FT56968     Arizona              2590.096027       No
# 59             59  EP83939     Arizona              5575.751228       No
# 67             67  KR35099  Washington              7507.455372      Yes
# ...           ...      ...         ...                      ...      ...
# 10801       10801  AP56340  Washington              5384.671725       No
# 10816       10816  AW71157  California              5531.723723       No
# 10833       10833  OQ99704  Washington              3981.775889       No
# 10834       10834  FU99476  Washington              6770.306834       No
# 10905       10905  FE99816      Nevada             15563.369440       No
#
#        coverage             education effective_to_date employmentstatus  \
# ...

# %%
marketing['number_of_open_complaints'] = marketing['number_of_open_complaints'].fillna('0')
len(marketing[marketing['number_of_open_complaints'].isna()==True])
# Out:
# 0

# %%
#6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.
marketing['months'] = marketing['effective_to_date']
marketing['months'] = pd.to_datetime(marketing['effective_to_date'], errors='coerce')
display(marketing.head())
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
first_quarter = marketing[(marketing['months'].dt.month >= 1) & (marketing['months'].dt.month <= 3)]
display(first_quarter)
print(first_quarter.shape)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
# The shape of the dataframe is the same after the filter, and is because the data are just from january and february. 
display(marketing['months'].value_counts(dropna=False)) 
len(marketing[marketing['months'].isna()==True])
# Out:
# 2011-01-10    239
# 2011-01-27    239
# 2011-01-31    224
# 2011-01-17    221
# 2011-02-14    221
# 2011-01-26    220
# 2011-01-03    216
# 2011-01-19    212
# 2011-02-27    205
# 2011-01-28    203
# 2011-02-26    202
# 2011-01-20    201
# 2011-01-21    199
# 2011-02-04    198
# 2011-02-07    197
# 2011-02-19    196
# 2011-02-03    195
# 2011-01-11    195
# 2011-01-05    193
# 2011-02-28    192
# 2011-02-22    191
# 2011-01-02    191
# 2011-02-18    186
# 2011-02-10    186
# 2011-02-11    184
# 2011-01-23    184
# 2011-02-12    183
# 2011-01-18    183
# 2011-02-25    183
# 2011-01-08    182
# 2011-01-29    182
# 2011-01-09    182
# 2011-02-05    181
# 2011-02-01    181
# 2011-02-02    181
# 2011-02-09    180
# 2011-01-14    180
# 2011-01-24    179
# 2011-02-21    178
# 2011-01-07    178
# 2011-02-23    176
# 2011-01-30    173
# 2011-01-15    172
# 2011-01-16    172
# 2011-01-13    171
# 2011-01-01    171
# 2011-02-06    171
# 2011-01-25    168
# 2011-02-13    168
# 2011-02-16    167
# ...

# %%
#7. BONUS: Put all the previously mentioned data transformations into a function.
